# %% [markdown]
# # Yolov8 Based Refrigerator Indoor Material Detection: Train

# %% [markdown]
# ## 00. Install required dependencies

# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached numpy-1.26.2-cp39-cp39-win_amd64.whl.metadata (61 kB)
# ...
#   Using cached opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached Pillow-10.1.0-cp39-cp39-win_amd64.whl.metadata (9.6 kB)
# ...
#   Using cached PyYAML-6.0.1-cp39-cp39-win_amd64.whl.metadata (2.1 kB)
# ...
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.4 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 60.4/60.4 kB 796.2 kB/s eta 0:00:00
# ...
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# ...
#   Using cached contourpy-1.2.0-cp39-cp39-win_amd64.whl.metadata (5.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.46.0-cp39-cp39-win_amd64.whl.metadata (159 kB)
# ...

# %% [markdown]
# ## 0. Import dependencies

# %%
import os
from ultralytics import YOLO

# %%
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: C:\My_Files\UpWork_jobs\refrigerator_object_detection_YOLOv8

# %% [markdown]
# ## 1. Load the model

# %%
# Load a model
model = YOLO()
#model = YOLO("yolov8n.yaml")  # build a new model from scratch
#model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# %% [markdown]
# ## 2. Use the model to train

# %%
# Use the model
model.train(data="C:/My_Files/UpWork_jobs/refrigerator_object_detection_YOLOv8/data.yml", epochs=10)  # train the model
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.9.13 torch-2.1.2+cpu CPU (Intel Core(TM) i7-5600U 2.60GHz)
# ...
